# %% [markdown]
# # 鸢尾花数据可视化

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
# 这里直接引入sklearn里的数据集，iris鸢尾花
from sklearn.datasets import load_iris 
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target

df = pd.DataFrame(data = iris.data, columns = iris.feature_names)
df['class'] = iris.target
df['class'] = df['class'].map({0: iris.target_names[0], 1: iris.target_names[1], 2: iris.target_names[2]})
df.head(10)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          class
# 0       setosa
# ...

# %%
plt.scatter(iris_X[:50,1],iris_X[:50,0],label='setosa',marker='o')
plt.scatter(iris_X[50:100,1],iris_X[50:100,0],label='versicolor',marker='x')
plt.scatter(iris_X[100:,1],iris_X[100:,0],label='virginica',marker='+')
plt.xlabel('sepal width(cm)')
plt.ylabel('sepal length(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %%
plt.scatter(iris_X[:50,2],iris_X[:50,0],label='setosa',marker='o')
plt.scatter(iris_X[50:100,2],iris_X[50:100,0],label='versicolor',marker='x')
plt.scatter(iris_X[100:,2],iris_X[100:,0],label='virginica',marker='+')
plt.xlabel('petal length(cm)')
plt.ylabel('sepal length(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %%
plt.scatter(iris_X[:50,2],iris_X[:50,1],label='setosa',marker='o')
plt.scatter(iris_X[50:100,2],iris_X[50:100,1],label='versicolor',marker='x')
plt.scatter(iris_X[100:,2],iris_X[100:,1],label='virginica',marker='+')
plt.xlabel('petal length(cm)')
plt.ylabel('sepal width(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %%
plt.scatter(iris_X[:50,3],iris_X[:50,0],label='setosa',marker='o')
plt.scatter(iris_X[50:100,3],iris_X[50:100,0],label='versicolor',marker='x')
plt.scatter(iris_X[100:,3],iris_X[100:,0],label='virginica',marker='+')
plt.xlabel('petal width(cm)')
plt.ylabel('sepal length(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %%
plt.scatter(iris_X[:50,3],iris_X[:50,1],label='setosa',marker='o')
plt.scatter(iris_X[50:100,3],iris_X[50:100,1],label='versicolor',marker='x')
plt.scatter(iris_X[100:,3],iris_X[100:,1],label='virginica',marker='+')
plt.xlabel('petal width(cm)')
plt.ylabel('sepal width(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %%
plt.scatter(iris_X[:50,3],iris_X[:50,2],label='setosa',marker='o')
plt.scatter(iris_X[50:100,3],iris_X[50:100,2],label='versicolor',marker='x')
plt.scatter(iris_X[100:,3],iris_X[100:,2],label='virginica',marker='+')
plt.xlabel('petal width(cm)')
plt.ylabel('petal length(cm)')
plt.title("actual result")
plt.legend()
plt.show()

# %% [markdown]
# # 鸢尾花数据的3D可视化

# %%
##画个简单三维图
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
 
ax = plt.figure().add_subplot(projection = '3d')
#基于ax变量绘制三维图
#xs表示x方向的变量
#ys表示y方向的变量
#zs表示z方向的变量，这三个方向上的变量都可以用list的形式表示
#m表示点的形式，o是圆形的点，^是三角形（marker)
#c表示颜色（color for short）
ax.scatter(xs, ys, zs, c = 'r', marker = '^')
 
#设置坐标轴
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
 
#显示图像
plt.show()
 
ax = plt.figure().add_subplot(111, projection = '3d')
 
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [85], in <cell line: 12>()
#       5 ax = plt.figure().add_subplot(111, projection = '3d')
#       6 #基于ax变量绘制三维图
#       7 #xs表示x方向的变量
#       8 #ys表示y方向的变量
#       9 #zs表示z方向的变量，这三个方向上的变量都可以用list的形式表示
#      10 #m表示点的形式，o是圆形的点，^是三角形（marker)
#      11 #c表示颜色（color for short）
# ---> 12 ax.scatter(xs, ys, zs, c = 'r', marker = '^') #点为红色三角形
#      14 #设置坐标轴
#      15 ax.set_xlabel('X Label')
#
# NameError: name 'xs' is not defined

# %% [markdown]
# # 使用PCA（主成分分析）对数据进行降维

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition

X = iris.data
y = iris.target

# PCA降维度
pca = decomposition.PCA(n_components=3)  #降到三维 
pca.fit(X)
X = pca.transform(X)
#3D图
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# 重新排序标签，使其颜色与群集结果匹配  
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.set_xlabel('第一特征向量')
ax.set_ylabel('第二特征向量')
ax.set_zlabel('第三特征向量')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# C:\Users\xiaochang\AppData\Local\Temp\ipykernel_26948\856285967.py:14: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
# C:\Users\xiaochang\AppData\Local\Temp\ipykernel_26948\856285967.py:25: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.choose(y, [1, 2, 0]).astype(np.float)

# %%
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 15.2/15.2 MB 3.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\xiaochang\py3\Scripts\python.exe -m pip install --upgrade pip' command.
